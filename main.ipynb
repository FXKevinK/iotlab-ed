# %%
import json

# %%
def run_command(cmd):
    val = !{cmd}
    val = [str(i).strip() for i in val]
    result = json.loads("".join(val))
    return result

# %%
cmd = "iotlab-status --experiments-running"
result = run_command(cmd)

# %%
result
# Out:
# {'items': [{'effective_duration': 198,
#    'id': 351880,
#    'name': 'code24rep1',
#    'nb_nodes': 5,
#    'nodes': ['m3-15.grenoble.iot-lab.info',
#     'm3-20.grenoble.iot-lab.info',
#     'm3-16.grenoble.iot-lab.info',
#     'm3-18.grenoble.iot-lab.info',
#     'm3-14.grenoble.iot-lab.info'],
#    'scheduled_date': '2022-12-31T10:39:00Z',
#    'start_date': '2022-12-31T10:39:00Z',
#    'state': 'Running',
#    'stop_date': '1970-01-01T00:00:00Z',
#    'submission_date': '2022-12-31T10:38:59Z',
#    'submitted_duration': 3600,
#    'user': 'kietzman'},
#   {'effective_duration': 197,
#    'id': 351881,
#    'name': 'code24rep3',
#    'nb_nodes': 5,
#    'nodes': ['m3-180.grenoble.iot-lab.info',
#     'm3-181.grenoble.iot-lab.info',
#     'm3-177.grenoble.iot-lab.info',
#     'm3-178.grenoble.iot-lab.info',
#     'm3-179.grenoble.iot-lab.info'],
#    'scheduled_date': '2022-12-31T10:40:46Z',
#    'start_date': '2022-12-31T10:40:46Z',
#    'state': 'Running',
# ...
